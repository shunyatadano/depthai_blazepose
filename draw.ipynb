plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.scatter(x_coords, y_coords, c='red', s=50, alpha=0.7)
for i, (x, y) in enumerate(zip(x_coords, y_coords)):
    plt.annotate(str(i), (x, y), xytext=(5, 5), textcoords='offset points', fontsize=8)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.grid(True, alpha=0.3)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('BlazePose Keypoints (X-Y plane)')
plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)
plt.axvline(x=0, color='k', linestyle='--', alpha=0.3)

# %%
# Plot X-Z plane
plt.subplot(2, 2, 2)
plt.scatter(x_coords, z_coords, c='blue', s=50, alpha=0.7)
for i, (x, z) in enumerate(zip(x_coords, z_coords)):
    plt.annotate(str(i), (x, z), xytext=(5, 5), textcoords='offset points', fontsize=8)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.grid(True, alpha=0.3)
plt.xlabel('X')
plt.ylabel('Z')
plt.title('BlazePose Keypoints (X-Z plane)')
plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)
plt.axvline(x=0, color='k', linestyle='--', alpha=0.3)

# %%
# Plot Y-Z plane
plt.subplot(2, 2, 3)
plt.scatter(y_coords, z_coords, c='green', s=50, alpha=0.7)
for i, (y, z) in enumerate(zip(y_coords, z_coords)):
    plt.annotate(str(i), (y, z), xytext=(5, 5), textcoords='offset points', fontsize=8)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.grid(True, alpha=0.3)
plt.xlabel('Y')
plt.ylabel('Z')
plt.title('BlazePose Keypoints (Y-Z plane)')
plt.axhline(y=0, color='k', linestyle='--', alpha=0.3)
plt.axvline(x=0, color='k', linestyle='--', alpha=0.3)

# %%
# 3D plot with larger figure size
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(16, 12))  # Increase figure size
ax = plt.subplot(2, 2, 4, projection='3d')
ax.scatter(x_coords, y_coords, z_coords, c='purple', s=50, alpha=0.7)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('BlazePose Keypoints (3D)')

plt.tight_layout()
plt.show()  # Dragging to rotate is enabled by default

# %%
# Print keypoint statistics
print(f"Number of keypoints: {len(keypoints_array)}")
print(f"X range: {x_coords.min():.3f} to {x_coords.max():.3f}")
print(f"Y range: {y_coords.min():.3f} to {y_coords.max():.3f}")
print(f"Z range: {z_coords.min():.3f} to {z_coords.max():.3f}")

# Display first few keypoints
print("\nFirst 5 keypoints (x, y, z):")
for i in range(min(5, len(keypoints_array))):
    print(f"Point {i}: ({keypoints_array[i, 0]:.3f}, {keypoints_array[i, 1]:.3f}, {keypoints_array[i, 2]:.3f})")
# Out:
# Number of keypoints: 33
# X range: -0.275 to 0.295
# Y range: -0.342 to 0.299
# Z range: -0.788 to 0.639
#
# First 5 keypoints (x, y, z):
# Point 0: (-0.121, -0.227, 0.604)
# Point 1: (-0.119, -0.212, 0.633)
# Point 2: (-0.111, -0.206, 0.633)
# Point 3: (-0.115, -0.209, 0.633)
# Point 4: (-0.151, -0.236, 0.639)
